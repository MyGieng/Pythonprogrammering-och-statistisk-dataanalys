# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?
#
# Svar: 1. object oriented approach  - denna är rekommenderad att använda
#     2. pyplot/matlab

# %% [markdown]
# Explain shortly what a figure, axes, axis and an artist is in Matplotlib.
#
# svar:
# figure: Hela figuren och kan betraktas som en canvas
# axes: en del av figure där datan kan ritas på,
# axis: hur axlarna ska visas med hjälp av markeringar och texter, för att göra det mer förståeligt.
# artist: allt som syns i figure

# %% [markdown]
# When plotting in Matplotlib, what is the expected input data type?
#
#  Svar: numpy arrays, listor i form av siffror, texter som är beskrivande

# %% [markdown]
# Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
x = np.linspace(-4, 4)
y = x**2

#OO 
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title = ("Grafen y = x^2")
ax.set_xlabel("x label")
ax.set_ylabel("y label")

plt.show()


#Pyplot

plt.plot(x, y)
plt.title("Grafen y = x^2")
plt.xlabel("x axel")
plt.ylabel("y axel")
plt.show()

# %% [markdown]
# Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(random_data_x, random_data_y)
ax.plot(x, y)
ax.set_title("scatter plot")
ax.set_xlabel("x axel")
ax.set_ylabel("y axel")
plt.show()

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(names, values)
ax.set_title("bar plot")
ax.set_xlabel("frukt")
ax.set_ylabel("antal")
plt.show()
